# %% [markdown]
# # 02 Event Definition
#
# Explore predeclared stress labels, event phases, and overlapping windows.

# %%
# TODO: compare drawdown, volatility, VIX, joint-stress, and time-to-event labels.
