# %% [markdown]
# # 03 Market Features
#
# Build and inspect structured market, options, futures, credit, liquidity, and macro features.

# %%
# TODO: audit feature transformations and as-of availability timestamps.
