# %% [markdown]
# # 06 Evaluation
#
# Report rare-event metrics, calibration, lead time, false alarms, and event-level detection.

# %%
# TODO: build reliability diagrams, event-level tables, and model comparison intervals.
