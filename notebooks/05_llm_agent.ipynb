# %% [markdown]
# # 05 LLM Agent
#
# Evaluate mock, local open-weight, sanitized, placebo, hybrid, and contaminated agent conditions.

# %%
# TODO: run strict-schema agent forecasts with logged prompt and context hashes.
